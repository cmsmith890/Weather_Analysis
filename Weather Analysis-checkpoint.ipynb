# %%
import numpy
import scipy.stats
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("bmh")

data = pandas.read_csv("storm_data_search_results.csv")
data.head()
# Out:
#    EVENT_ID    CZ_NAME_STR BEGIN_LOCATION BEGIN_DATE  BEGIN_TIME  \
# 0    422522    HICKMAN CO.        CLINTON  1/12/2013        1340
# 1    422501  MCCRACKEN CO.       LONE OAK  1/12/2013        1440
# 2    424834    BALLARD CO.      LA CENTER  1/29/2013        2235
# 3    428959  MCCRACKEN CO.       CAMMELIA  1/29/2013        2247
# 4    424835     GRAVES CO.          LOWES  1/29/2013        2250
#
#           EVENT_TYPE  MAGNITUDE TOR_F_SCALE  DEATHS_DIRECT  INJURIES_DIRECT  \
# 0  Thunderstorm Wind         52                          0                0
# 1  Thunderstorm Wind         56                          0                0
# 2  Thunderstorm Wind         52                          0                0
# 3  Thunderstorm Wind         56                          0                0
# 4  Thunderstorm Wind         61                          0                0
#
#    ...  END_LOCATION   END_DATE END_TIME BEGIN_LAT BEGIN_LON  END_LAT  \
# 0  ...       CLINTON  1/12/2013     1340   36.6411  -88.9800  36.6411
# 1  ...       PADUCAH  1/12/2013     1445   37.0083  -88.6700  37.0647
# 2  ...     LA CENTER  1/29/2013     2235   37.0266  -88.9800  37.0266
# 3  ...      CAMMELIA  1/29/2013     2247   37.0139  -88.8078  37.0139
# 4  ...         LOWES  1/29/2013     2250   36.8800  -88.7700  36.8800
#
#    END_LON                                    EVENT_NARRATIVE  \
# 0 -88.9800  A grain bin was heavily damaged. The contents ...
# 1 -88.6108  Several large trees up to three feet in diamet...
# 2 -88.9800  Trees were blown down. There was slight struct...
# 3 -88.8078  A barn roof was partially blown off on Highway...
# 4 -88.7700  A well house was destroyed. Some shingles were...
#
#                                    EPISODE_NARRATIVE  ABSOLUTE_ROWNUMBER
# 0  During the afternoon, a supercell thunderstorm...                   1
# 1  During the afternoon, a supercell thunderstorm...                   2
# 2  A line of thunderstorms intensified as it move...                   3
# 3  A line of thunderstorms intensified as it move...                   4
# 4  A line of thunderstorms intensified as it move...                   5
#
# [5 rows x 39 columns]

# %%
data.columns
# Out:
# Index(['EVENT_ID', 'CZ_NAME_STR', 'BEGIN_LOCATION', 'BEGIN_DATE', 'BEGIN_TIME',
#        'EVENT_TYPE', 'MAGNITUDE', 'TOR_F_SCALE', 'DEATHS_DIRECT',
#        'INJURIES_DIRECT', 'DAMAGE_PROPERTY_NUM', 'DAMAGE_CROPS_NUM',
#        'STATE_ABBR', 'CZ_TIMEZONE', 'MAGNITUDE_TYPE', 'EPISODE_ID', 'CZ_TYPE',
#        'CZ_FIPS', 'WFO', 'INJURIES_INDIRECT', 'DEATHS_INDIRECT', 'SOURCE',
#        'FLOOD_CAUSE', 'TOR_LENGTH', 'TOR_WIDTH', 'BEGIN_RANGE',
#        'BEGIN_AZIMUTH', 'END_RANGE', 'END_AZIMUTH', 'END_LOCATION', 'END_DATE',
#        'END_TIME', 'BEGIN_LAT', 'BEGIN_LON', 'END_LAT', 'END_LON',
#        'EVENT_NARRATIVE', 'EPISODE_NARRATIVE', 'ABSOLUTE_ROWNUMBER'],
#       dtype='object')

# %%
print(data.describe())

# Histogram of magnitudes
plt.hist(data['MAGNITUDE'], bins=20, edgecolor='black')
plt.xlabel('Magnitude')
plt.ylabel('Frequency')
plt.title('Distribution of Magnitudes')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8480\2053507891.py in <module>
# ----> 1 print(data.describe())
#       2
#       3 # Histogram of magnitudes
#       4 plt.hist(data['MAGNITUDE'], bins=20, edgecolor='black')
#       5 plt.xlabel('Magnitude')
#
# NameError: name 'data' is not defined

# %%
# Convert date strings to datetime objects
data['BEGIN_DATE'] = pd.to_datetime(data['BEGIN_DATE'])

# Plot the number of events over time
plt.plot(data['BEGIN_DATE'], data['MAGNITUDE'], marker='o', linestyle='-', label='Magnitude')
plt.xlabel('Date')
plt.ylabel('Magnitude')
plt.title('Magnitude Variation Over Time')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8480\2503104091.py in <module>
#       1 # Convert date strings to datetime objects
# ----> 2 data['BEGIN_DATE'] = pd.to_datetime(data['BEGIN_DATE'])
#       3
#       4 # Plot the number of events over time
#       5 plt.plot(data['BEGIN_DATE'], data['MAGNITUDE'], marker='o', linestyle='-', label='Magnitude')
#
# NameError: name 'pd' is not defined

# %%
# Calculate correlation matrix
correlation_matrix = data.corr()

# Heatmap to visualize the correlation matrix
plt.figure(figsize=(12, 8))
plt.imshow(correlation_matrix, cmap='coolwarm', interpolation='nearest')
plt.colorbar()
plt.xticks(range(len(correlation_matrix)), correlation_matrix.columns, rotation=90)
plt.yticks(range(len(correlation_matrix)), correlation_matrix.columns)
plt.title('Correlation Matrix')
plt.show()

# %%
# Check for missing values
print(data.isnull().sum())

# Remove rows with missing values
data.dropna(inplace=True)

# Or impute missing values with mean or median (if applicable)
data['MAGNITUDE'].fillna(data['MAGNITUDE'].mean(), inplace=True)
